# %% [markdown]
# # Fetching data on university postcodes using an API
#
# This notebook documents the process followed in the third session on Python, focusing on APIs.
#
# First we import the `pandas` library which we'll need to import the data from the API.

# %%
import pandas as pd

# %% [markdown]
# Our scenario is that we have data on universities but we need to be able to aggregate those universities into the particular region they are in.
#
# We also might want to query the police API for data on crimes - and for that we will need the lat/long of each university.
#
# So we need to import the data on university postcodes that we are going to use to 'query' the postcodes API for the region and lat/long.

# %%
#import a CSV of university names and postcodes, shared from Google Drive
unidataurl = "https://docs.google.com/spreadsheets/d/e/2PACX-1vT9cEtSDCK6vrYxCIWv7Tg7fxCD8z3p_FoTj6b-3ipE4jYuH06ozsmz02oYqNoRHZlIGz5ECyfWZJbh/pub?output=csv"

# %%
#read in the CSV at that URL
unidata = pd.read_csv(unidataurl)
#preview it
unidata
# Out:
#                                             uni  postcode
# 0                      Anglia Ruskin University   CM1 1SQ
# 1                              Aston University    B4 7ET
# 2                             Bangor University  LL57 2DG
# 3                           Bath Spa University   BA2 9BN
# 4                              Birkbeck College  WC1E 7HX
# ..                                          ...       ...
# 161     University of the Highlands and Islands   IV3 5SQ
# 162  University of the West of England, Bristol  BS16 1QY
# 163          University of the West of Scotland   PA1 2BE
# 164                             Writtle College   CM1 3RR
# 165                     York St John University  YO31 7EX
#
# [166 rows x 2 columns]

# %% [markdown]
# ## Query the API
#
# Now let's use that data to query the API, starting with one postcode as a test.

# %%
#grab the first postcode in our data
firstpostcode = unidata['postcode'][0]
firstpostcode
# Out:
# 'CM1 1SQ'

# %%
#form the URL - an endpoint - for that
#start with the base URL that we need to add the postcode to
baseurl = "https://api.postcodes.io/postcodes/"
#remove any spaces
firstpostcode = firstpostcode.replace(' ','')
#create a full URL
fullurl = baseurl+firstpostcode
print(fullurl)
#fetch the json
json = pd.read_json(fullurl)
#drill down into it to grab the lat, long and region
lat = json['result']['latitude']
lng = json['result']['longitude']
region = json['result']['region']
#check
print(lat)
print(lng)
print(region)
# Out:
# https://api.postcodes.io/postcodes/CM11SQ
# 51.741381
# 0.474495
# East of England

# %% [markdown]
# ## Create a dataframe to hold the data we get - and loop to create rows for that dataframe
#
# Now we've tested it on one postcode, we can create a loop to go through multiple postcodes.
#
# To begin with we can limit the loop to the first five items by adding the index 'slice' `[:5]` to the start of the loop like so:
#
# `for i in unidata['postcode'][:5]:`
#
# Then, once it's working on those 5, we can remove it so we loop through all items.
#
# When we do extend it to all items, we will hit an error (a `HTTPError`) with at least one postcode (b422su) because the API doesn't have data for it.
#
# To solve that problem, we add a `try/except` branch to the loop, which means it doesn't stop when it hits the error, but just does something else (`except:`) instead, storing the fact that for those postcodes there was no data.

# %%
#create a dataframe - it's only got one column for now
apidata = pd.DataFrame(columns=['postcode'])

#loop through the postcodes - first 5 to begin with
for i in unidata['postcode']:
  #replace the space
  postcodeclean = i.replace(' ','')
  #check it worked
  print(postcodeclean)
  #create the url
  jsonurl = baseurl+postcodeclean
  #check
  print(jsonurl)
  #try the code after the colon - but if it breaks it won't stop the loop
  #instead it will skip to 'except' below
  #DON'T FORGET THE COLON!
  try:
    #fetch from url
    json = pd.read_json(jsonurl)
    #create new dictionary object
    newrow = {}
    #fill that dictionary under the key 'postcode'
    newrow['postcode'] = i
    #grab the lat, long and region
    lat = json['result']['latitude']
    lng = json['result']['longitude']
    region = json['result']['region']
    #add them to the dictionary
    newrow['latitude'] = lat
    newrow['longitude'] = lng
    newrow['region'] = region
    newrow['API URL'] = jsonurl
    #show the dictionary
    print(newrow)
    #add to the dataframe
    apidata = apidata.append(newrow, ignore_index=True)
  #except specifies what to do if the 'try' chunk throws an error
  #(for example because the page doesn't exist)
  #DON'T FORGET THE COLON!
  except:
    #create new dictionary object
    newrow = {}
    #fill it so we know the API doesn't have data for this postcode 
    newrow['postcode'] = i
    newrow['latitude'] = "NO DATA"
    newrow['longitude'] = "NO DATA"
    newrow['region'] = "NO DATA"
    #add to the dataframe
    apidata = apidata.append(newrow, ignore_index=True)

print(apidata)

# %%
apidata
# Out:
#      postcode latitude longitude                    region
# 0     CM1 1SQ  51.7414  0.474495           East of England
# 1      B4 7ET  52.4866  -1.89095             West Midlands
# 2    LL57 2DG  53.2292  -4.12944                      None
# 3     BA2 9BN  51.3732  -2.44091                South West
# 4    WC1E 7HX  51.5219 -0.130359                    London
# ..        ...      ...       ...                       ...
# 161   IV3 5SQ  57.4694  -4.23024                      None
# 162  BS16 1QY  51.5011  -2.54746                South West
# 163   PA1 2BE  55.8435  -4.42997                      None
# 164   CM1 3RR  51.7372  0.428133           East of England
# 165  YO31 7EX  53.9648  -1.07954  Yorkshire and The Humber
#
# [166 rows x 4 columns]

# %%
#and export
apidata.to_csv("apidata.csv")

# %% [markdown]
# ## Version where we keep the uni name too
#
# In the loop above we only retain the postcodes from the original data, so we'd have to merge it back with the original data to get the university names as well.
#
# Alternatively, we could write our loop using indices instead, fetching both the postcode *and* the university name, and storing both in the resulting dataframe.
#
# First, here's some code demonstrating the concept of using indices instead:

# %%
#find out how many universities there are in our data
uninumbers = len(unidata)
#it's 166
print(uninumbers)
#create a range of indices from 0 to 165 (the 166th item), and loop through those
for i in range(0,uninumbers):
  print(i)
  #fetch the postcode at that index
  print(unidata['postcode'][i])
  #fetch the uni at that index
  print(unidata['uni'][i])
# Out:
# 166
# 0
# CM1 1SQ
# Anglia Ruskin University
# 1
# B4 7ET
# Aston University
# 2
# LL57 2DG
# Bangor University
# 3
# BA2 9BN
# Bath Spa University
# 4
# WC1E 7HX
# Birkbeck College
# 5
# B42 2SU
# Birmingham City University
# 6
# LN1 3DY
# Bishop Grosseteste University College Lincoln
# 7
# BH12 5BB
# Bournemouth University
# 8
# UB8 3PH
# Brunel University
# 9
# HP11 2JZ
# Buckinghamshire New University
# 10
# CT1 1UT
# Canterbury Christ Church University
# 11
# CF5 2SG
# Cardiff Metropolitan University
# 12
# CF10 3AT
# Cardiff University
# 13
# NW3 3HY
# Central School of Speech and Drama(The)
# 14
# WC2R 0RN
# Courtauld Institute of Art
# 15
# CV1 5FB
# Coventry University
# 16
# MK43 0AL
# Cranfield University
# 17
# LE1 9BH
# De Montfort University
# 18
# L39 4QP
# Edge Hill University
# 19
# EH11 4BN
# Edinburgh Napier University
# 20
# G4 0BA
# Glasgow Caledonian University
# 21
# G3 6RQ
# Glasgow School of Art
# 22
# LL11 2AW
# Glyndwr University
# 23
# SE14 6NW
# Goldsmiths' College
# 24
# EC2Y 8DT
# Guildhall School of Music and Drama
# 25
# TF10 8NB
# Harper Adams University
# 26
# EH14 4AS
# Heriot-Watt University
# 27
# W8 5HN
# Heythrop College
# 28
# SW7 2AZ
# Imperial College of Science, Technology and Medicine
# 29
# SW7 3RP
# Institute of Cancer Research: Royal Cancer Hospital (The)
# 30
# WC1H 0AL
# Institute of Education, University of London
# 31
# WC2R 2LS
# King's College London
# 32
# KT1 1LQ
# Kingston University
# 33
# LS2 9AQ
# Leeds College of Art
# 34
# LS2 7PD
# Leeds College of Music
# 35
# LS1 3HE
# Leeds Metropolitan University
# 36
# LS18 5HD
# Leeds Trinity University College
# 37
# L16 9JD
# Liverpool Hope University
# 38
# L3 5UX
# Liverpool John Moores University
# 39
# NW1 4SA
# London Business School
# 40
# N7 8DB
# London Metropolitan University
# 41
# WC2A 2AE
# London School of Economics & Political Science
# 42
# WC1E 7HT
# London School of Hygiene and Tropical Medicine
# 43
# SE1 0AA
# London South Bank University
# 44
# LE11 3TU
# Loughborough University
# 45
# NW4 4BT
# Middlesex University
# 46
# B32 3NT
# Newman University College
# 47
# LS7 4BH
# Northern School of Contemporary Dance
# 48
# NR2 4SN
# Norwich University College of the Arts
# 49
# NG1 4BU
# Nottingham Trent University
# 50
# MK7 6AA
# Open University(The)
# 51
# OX3 0BP
# Oxford Brookes University
# 52
# SY23 2AX
# Prifysgol Aberystwyth
# 53
# EH21 6UU
# Queen Margaret University, Edinburgh
# 54
# E1 4NS
# Queen Mary and Westfield College, University of London
# 55
# SE10 0EW
# Ravensbourne Limited
# 56
# SW15 5PJ
# Roehampton University
# 57
# DA15 9DF
# Rose Bruford College
# 58
# NW1 5HT
# Royal Academy of Music
# 59
# GL7 6JS
# Royal Agricultural College
# 60
# SW7 2EU
# Royal College of Art(The)
# 61
# SW7 2BS
# Royal College of Music
# 62
# G2 3DB
# Royal Conservatoire of Scotland
# 63
# TW20 0EX
# Royal Holloway College and Bedford New College
# 64
# M13 9RD
# Royal Northern College of Music
# 65
# CF10 3ER
# Royal Welsh College of Music and Drama Limited
# 66
# WC1H 0XG
# School of Oriental and African Studies
# 67
# WC1N 1AX
# School of Pharmacy University of London(The)
# 68
# S1 1WB
# Sheffield Hallam University
# 69
# SO14 0YN
# Southampton Solent University
# 70
# EH9 3JG
# Sruc
# 71
# SW17 0RE
# St George's Hospital Medical School
# 72
# BT12 6FE
# St Mary's University College
# 73
# TW1 4SX
# St Mary's University College, Twickenham
# 74
# ST4 2DE
# Staffordshire University
# 75
# BT9 5DY
# Stranmillis University College
# 76
# SA1 6ED
# Swansea Metropolitan University
# 77
# SA2 8PP
# Swansea University
# 78
# TS1 3BA
# Teesside University
# 79
# BH12 5HH
# The Arts University College at Bournemouth
# 80
# EC1V 0HB
# The City University
# 81
# WC1H 9JJ
# The Conservatoire for Dance and Drama
# 82
# L1 9HF
# The Liverpool Institute for Performing Arts
# 83
# M15 6BH
# The Manchester Metropolitan University
# 84
# BT7 1NN
# The Queen's University of Belfast
# 85
# AB10 7FY
# The Robert Gordon University
# 86
# NW1 0TU
# The Royal Veterinary College
# 87
# BL3 5AB
# The University of Bolton
# 88
# MK18 1EG
# The University of Buckingham
# 89
# PO19 6PE
# The University of Chichester
# 90
# CA1 2HH
# The University of Cumbria
# 91
# M13 9PL
# The University of Manchester
# 92
# NN2 5PH
# The University of Northampton
# 93
# W5 5RF
# The University of West London
# 94
# W1B 2HW
# The University of Westminster
# 95
# SE10 9JF
# Trinity Laban Conservatoire of Music and Dance Ltd
# 96
# IP4 1QJ
# University Campus Suffolk Ltd
# 97
# B3 1JB
# University College Birmingham
# 98
# TR11 4RH
# University College Falmouth
# 99
# WC1E 6BT
# University College London
# 100
# GU9 7DS
# University for the Creative Arts
# 101
# AB24 3FX
# University of Aberdeen
# 102
# DD1 1HG
# University of Abertay Dundee
# 103
# BA2 7AY
# University of Bath (The)
# 104
# LU1 3JU
# University of Bedfordshire
# 105
# B15 2TT
# University of Birmingham
# 106
# BD7 1DP
# University of Bradford
# 107
# BN2 4AT
# University of Brighton
# 108
# BS8 1TH
# University of Bristol
# 109
# CB2 1TN
# University of Cambridge
# 110
# PR1 2HE
# University of Central Lancashire
# 111
# CH1 4BJ
# University of Chester
# 112
# DE22 1GB
# University of Derby
# 113
# DD1 4HN
# University of Dundee
# 114
# DH1 3LE
# University of Durham
# 115
# NR4 7TJ
# University of East Anglia
# 116
# E16 2RD
# University of East London
# 117
# EH1 1HT
# University of Edinburgh
# 118
# CO4 3SQ
# University of Essex
# 119
# EX4 4PY
# University of Exeter
# 120
# CF37 1DL
# University of Glamorgan / Prifysgol Morgannwg
# 121
# G12 8QQ
# University of Glasgow
# 122
# GL50 2RH
# University of Gloucestershire
# 123
# SE10 9LS
# University of Greenwich
# 124
# AL10 9AB
# University of Hertfordshire
# 125
# HD1 3DH
# University of Huddersfield
# 126
# HU6 7RX
# University of Hull
# 127
# ST5 5BG
# University of Keele
# 128
# CT2 7NZ
# University of Kent
# 129
# LA1 4YW
# University of Lancaster
# 130
# LS2 9JT
# University of Leeds
# 131
# LE1 7RH
# University of Leicester
# 132
# LN6 7TS
# University of Lincoln
# 133
# L69 3BX
# University of Liverpool
# 134
# WC1E 7HU
# University of London
# 135
# NE1 7RU
# University of Newcastle Upon Tyne
# 136
# NE1 8ST
# University of Northumbria at Newcastle
# 137
# NG7 2RD
# University of Nottingham
# 138
# OX1 2JD
# University of Oxford
# 139
# PL4 8AA
# University of Plymouth
# 140
# PO1 2UP
# University of Portsmouth
# 141
# RG6 6UR
# University of Reading
# 142
# M5 4WT
# University of Salford
# 143
# S10 2TN
# University of Sheffield
# 144
# SO17 1BJ
# University of Southampton
# 145
# KY16 9AJ
# University of St Andrews
# 146
# PL6 8BH
# University of St Mark & St John
# 147
# FK9 4LA
# University of Stirling
# 148
# G1 1XQ
# University of Strathclyde
# 149
# SR1 3SD
# University of Sunderland
# 150
# GU2 7XH
# University of Surrey
# 151
# BN1 9RH
# University of Sussex
# 152
# BT52 1SA
# University of Ulster
# 153
# CF10 3NS
# University of Wales Prifysgol Cymru
# 154
# SA31 3EP
# University of Wales: Trinity Saint David
# 155
# CV4 7AL
# University of Warwick
# 156
# SO22 4NR
# University of Winchester
# 157
# WV1 1LY
# University of Wolverhampton
# 158
# WR2 6AJ
# University of Worcester
# 159
# YO10 5DD
# University of York
# 160
# WC1V 7EY
# University of the Arts, London
# 161
# IV3 5SQ
# University of the Highlands and Islands
# 162
# BS16 1QY
# University of the West of England, Bristol
# 163
# PA1 2BE
# University of the West of Scotland
# 164
# CM1 3RR
# Writtle College
# 165
# YO31 7EX
# York St John University

# %% [markdown]
# Now this is what it looks like incorporated into a loop:

# %%
#create a dataframe - it's only got one column for now
apidata = pd.DataFrame(columns=['postcode'])

uninumbers = len(unidata)

#loop through the postcodes - first 5 to begin with
for i in range(0,uninumbers):
  print("index", i)
  postcode = unidata['postcode'][i]
  #replace the space
  postcodeclean = postcode.replace(' ','')
  #check it worked
  print(postcodeclean)
  #create the url
  jsonurl = baseurl+postcodeclean
  #check
  print(jsonurl)
  #try the code after the colon - but if it breaks it won't stop the loop
  #instead it will skip to 'except' below
  #DON'T FORGET THE COLON!
  try:
    #fetch from url
    json = pd.read_json(jsonurl)
    #create new dictionary object
    newrow = {}
    #fill that dictionary under the key 'postcode'
    newrow['postcode'] = postcode
    #and the uni
    newrow['university'] = unidata['uni'][i]
    #grab the lat, long and region
    lat = json['result']['latitude']
    lng = json['result']['longitude']
    region = json['result']['region']
    #add them to the dictionary
    newrow['latitude'] = lat
    newrow['longitude'] = lng
    newrow['region'] = region
    newrow['API URL'] = jsonurl
    #show the dictionary
    print(newrow)
    #add to the dataframe
    apidata = apidata.append(newrow, ignore_index=True)
  #except specifies what to do if the 'try' chunk throws an error
  #(for example because the page doesn't exist)
  #DON'T FORGET THE COLON!
  except:
    #create new dictionary object
    newrow = {}
    #fill it so we know the API doesn't have data for this postcode 
    newrow['postcode'] = postcode
    #and the uni
    newrow['university'] = unidata['uni'][i]
    newrow['latitude'] = "NO DATA"
    newrow['longitude'] = "NO DATA"
    newrow['region'] = "NO DATA"
    #add to the dataframe
    apidata = apidata.append(newrow, ignore_index=True)

print(apidata)
# Out:
# index 0
# CM11SQ
# https://api.postcodes.io/postcodes/CM11SQ
# {'postcode': 'CM1 1SQ', 'university': 'Anglia Ruskin University', 'latitude': 51.741381, 'longitude': 0.474495, 'region': 'East of England', 'API URL': 'https://api.postcodes.io/postcodes/CM11SQ'}
# index 1
# B47ET
# https://api.postcodes.io/postcodes/B47ET
# {'postcode': 'B4 7ET', 'university': 'Aston University', 'latitude': 52.486637, 'longitude': -1.890952, 'region': 'West Midlands', 'API URL': 'https://api.postcodes.io/postcodes/B47ET'}
# index 2
# LL572DG
# https://api.postcodes.io/postcodes/LL572DG
# {'postcode': 'LL57 2DG', 'university': 'Bangor University', 'latitude': 53.229193, 'longitude': -4.129437, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/LL572DG'}
# index 3
# BA29BN
# https://api.postcodes.io/postcodes/BA29BN
# {'postcode': 'BA2 9BN', 'university': 'Bath Spa University', 'latitude': 51.373209, 'longitude': -2.440912, 'region': 'South West', 'API URL': 'https://api.postcodes.io/postcodes/BA29BN'}
# index 4
# WC1E7HX
# https://api.postcodes.io/postcodes/WC1E7HX
# {'postcode': 'WC1E 7HX', 'university': 'Birkbeck College', 'latitude': 51.521891, 'longitude': -0.130359, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC1E7HX'}
# index 5
# B422SU
# https://api.postcodes.io/postcodes/B422SU
# index 6
# LN13DY
# https://api.postcodes.io/postcodes/LN13DY
# {'postcode': 'LN1 3DY', 'university': 'Bishop Grosseteste University College Lincoln', 'latitude': 53.243563, 'longitude': -0.5371389999999999, 'region': 'East Midlands', 'API URL': 'https://api.postcodes.io/postcodes/LN13DY'}
# index 7
# BH125BB
# https://api.postcodes.io/postcodes/BH125BB
# {'postcode': 'BH12 5BB', 'university': 'Bournemouth University', 'latitude': 50.742979, 'longitude': -1.897168, 'region': 'South West', 'API URL': 'https://api.postcodes.io/postcodes/BH125BB'}
# index 8
# UB83PH
# https://api.postcodes.io/postcodes/UB83PH
# {'postcode': 'UB8 3PH', 'university': 'Brunel University', 'latitude': 51.532838, 'longitude': -0.472856, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/UB83PH'}
# index 9
# HP112JZ
# https://api.postcodes.io/postcodes/HP112JZ
# {'postcode': 'HP11 2JZ', 'university': 'Buckinghamshire New University', 'latitude': 51.627509, 'longitude': -0.7520359999999999, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/HP112JZ'}
# index 10
# CT11UT
# https://api.postcodes.io/postcodes/CT11UT
# {'postcode': 'CT1 1UT', 'university': 'Canterbury Christ Church University', 'latitude': 51.276648, 'longitude': 1.085809, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/CT11UT'}
# index 11
# CF52SG
# https://api.postcodes.io/postcodes/CF52SG
# index 12
# CF103AT
# https://api.postcodes.io/postcodes/CF103AT
# {'postcode': 'CF10 3AT', 'university': 'Cardiff University', 'latitude': 51.489014, 'longitude': -3.179717, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/CF103AT'}
# index 13
# NW33HY
# https://api.postcodes.io/postcodes/NW33HY
# {'postcode': 'NW3 3HY', 'university': 'Central School of Speech and Drama(The)', 'latitude': 51.544325, 'longitude': -0.174205, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/NW33HY'}
# index 14
# WC2R0RN
# https://api.postcodes.io/postcodes/WC2R0RN
# {'postcode': 'WC2R 0RN', 'university': 'Courtauld Institute of Art', 'latitude': 51.510732, 'longitude': -0.116938, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC2R0RN'}
# index 15
# CV15FB
# https://api.postcodes.io/postcodes/CV15FB
# {'postcode': 'CV1 5FB', 'university': 'Coventry University', 'latitude': 52.405314, 'longitude': -1.500063, 'region': 'West Midlands', 'API URL': 'https://api.postcodes.io/postcodes/CV15FB'}
# index 16
# MK430AL
# https://api.postcodes.io/postcodes/MK430AL
# {'postcode': 'MK43 0AL', 'university': 'Cranfield University', 'latitude': 52.069817, 'longitude': -0.630801, 'region': 'East of England', 'API URL': 'https://api.postcodes.io/postcodes/MK430AL'}
# index 17
# LE19BH
# https://api.postcodes.io/postcodes/LE19BH
# {'postcode': 'LE1 9BH', 'university': 'De Montfort University', 'latitude': 52.629312, 'longitude': -1.137676, 'region': 'East Midlands', 'API URL': 'https://api.postcodes.io/postcodes/LE19BH'}
# index 18
# L394QP
# https://api.postcodes.io/postcodes/L394QP
# {'postcode': 'L39 4QP', 'university': 'Edge Hill University', 'latitude': 53.559608, 'longitude': -2.873836, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/L394QP'}
# index 19
# EH114BN
# https://api.postcodes.io/postcodes/EH114BN
# {'postcode': 'EH11 4BN', 'university': 'Edinburgh Napier University', 'latitude': 55.924076, 'longitude': -3.288471, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/EH114BN'}
# index 20
# G40BA
# https://api.postcodes.io/postcodes/G40BA
# {'postcode': 'G4 0BA', 'university': 'Glasgow Caledonian University', 'latitude': 55.86729, 'longitude': -4.250057, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/G40BA'}
# index 21
# G36RQ
# https://api.postcodes.io/postcodes/G36RQ
# {'postcode': 'G3 6RQ', 'university': 'Glasgow School of Art', 'latitude': 55.865948, 'longitude': -4.263662, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/G36RQ'}
# index 22
# LL112AW
# https://api.postcodes.io/postcodes/LL112AW
# {'postcode': 'LL11 2AW', 'university': 'Glyndwr University', 'latitude': 53.052626, 'longitude': -3.006109, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/LL112AW'}
# index 23
# SE146NW
# https://api.postcodes.io/postcodes/SE146NW
# {'postcode': 'SE14 6NW', 'university': "Goldsmiths' College", 'latitude': 51.474144, 'longitude': -0.035400999999999995, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SE146NW'}
# index 24
# EC2Y8DT
# https://api.postcodes.io/postcodes/EC2Y8DT
# {'postcode': 'EC2Y 8DT', 'university': 'Guildhall School of Music and Drama', 'latitude': 51.519517, 'longitude': -0.092374, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/EC2Y8DT'}
# index 25
# TF108NB
# https://api.postcodes.io/postcodes/TF108NB
# {'postcode': 'TF10 8NB', 'university': 'Harper Adams University', 'latitude': 52.77991, 'longitude': -2.425557, 'region': 'West Midlands', 'API URL': 'https://api.postcodes.io/postcodes/TF108NB'}
# index 26
# EH144AS
# https://api.postcodes.io/postcodes/EH144AS
# {'postcode': 'EH14 4AS', 'university': 'Heriot-Watt University', 'latitude': 55.909385, 'longitude': -3.320682, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/EH144AS'}
# index 27
# W85HN
# https://api.postcodes.io/postcodes/W85HN
# {'postcode': 'W8 5HN', 'university': 'Heythrop College', 'latitude': 51.499883, 'longitude': -0.190908, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/W85HN'}
# index 28
# SW72AZ
# https://api.postcodes.io/postcodes/SW72AZ
# {'postcode': 'SW7 2AZ', 'university': 'Imperial College of Science, Technology and Medicine', 'latitude': 51.498317, 'longitude': -0.176923, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SW72AZ'}
# index 29
# SW73RP
# https://api.postcodes.io/postcodes/SW73RP
# {'postcode': 'SW7 3RP', 'university': 'Institute of Cancer Research: Royal Cancer Hospital (The)', 'latitude': 51.490783, 'longitude': -0.181646, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SW73RP'}
# index 30
# WC1H0AL
# https://api.postcodes.io/postcodes/WC1H0AL
# {'postcode': 'WC1H 0AL', 'university': 'Institute of Education, University of London', 'latitude': 51.522977, 'longitude': -0.127965, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC1H0AL'}
# index 31
# WC2R2LS
# https://api.postcodes.io/postcodes/WC2R2LS
# {'postcode': 'WC2R 2LS', 'university': "King's College London", 'latitude': 51.511612, 'longitude': -0.116253, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC2R2LS'}
# index 32
# KT11LQ
# https://api.postcodes.io/postcodes/KT11LQ
# {'postcode': 'KT1 1LQ', 'university': 'Kingston University', 'latitude': 51.406309, 'longitude': -0.30786, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/KT11LQ'}
# index 33
# LS29AQ
# https://api.postcodes.io/postcodes/LS29AQ
# {'postcode': 'LS2 9AQ', 'university': 'Leeds College of Art', 'latitude': 53.808429, 'longitude': -1.5517750000000001, 'region': 'Yorkshire and The Humber', 'API URL': 'https://api.postcodes.io/postcodes/LS29AQ'}
# index 34
# LS27PD
# https://api.postcodes.io/postcodes/LS27PD
# {'postcode': 'LS2 7PD', 'university': 'Leeds College of Music', 'latitude': 53.79823, 'longitude': -1.5312519999999998, 'region': 'Yorkshire and The Humber', 'API URL': 'https://api.postcodes.io/postcodes/LS27PD'}
# index 35
# LS13HE
# https://api.postcodes.io/postcodes/LS13HE
# {'postcode': 'LS1 3HE', 'university': 'Leeds Metropolitan University', 'latitude': 53.80402, 'longitude': -1.548578, 'region': 'Yorkshire and The Humber', 'API URL': 'https://api.postcodes.io/postcodes/LS13HE'}
# index 36
# LS185HD
# https://api.postcodes.io/postcodes/LS185HD
# {'postcode': 'LS18 5HD', 'university': 'Leeds Trinity University College', 'latitude': 53.84878, 'longitude': -1.64735, 'region': 'Yorkshire and The Humber', 'API URL': 'https://api.postcodes.io/postcodes/LS185HD'}
# index 37
# L169JD
# https://api.postcodes.io/postcodes/L169JD
# {'postcode': 'L16 9JD', 'university': 'Liverpool Hope University', 'latitude': 53.391526999999996, 'longitude': -2.891907, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/L169JD'}
# index 38
# L35UX
# https://api.postcodes.io/postcodes/L35UX
# {'postcode': 'L3 5UX', 'university': 'Liverpool John Moores University', 'latitude': 53.403685, 'longitude': -2.973176, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/L35UX'}
# index 39
# NW14SA
# https://api.postcodes.io/postcodes/NW14SA
# {'postcode': 'NW1 4SA', 'university': 'London Business School', 'latitude': 51.526581, 'longitude': -0.161378, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/NW14SA'}
# index 40
# N78DB
# https://api.postcodes.io/postcodes/N78DB
# {'postcode': 'N7 8DB', 'university': 'London Metropolitan University', 'latitude': 51.551471, 'longitude': -0.11038099999999999, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/N78DB'}
# index 41
# WC2A2AE
# https://api.postcodes.io/postcodes/WC2A2AE
# {'postcode': 'WC2A 2AE', 'university': 'London School of Economics & Political Science', 'latitude': 51.514114, 'longitude': -0.11697099999999999, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC2A2AE'}
# index 42
# WC1E7HT
# https://api.postcodes.io/postcodes/WC1E7HT
# {'postcode': 'WC1E 7HT', 'university': 'London School of Hygiene and Tropical Medicine', 'latitude': 51.520925, 'longitude': -0.130687, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC1E7HT'}
# index 43
# SE10AA
# https://api.postcodes.io/postcodes/SE10AA
# {'postcode': 'SE1 0AA', 'university': 'London South Bank University', 'latitude': 51.498708, 'longitude': -0.101772, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SE10AA'}
# index 44
# LE113TU
# https://api.postcodes.io/postcodes/LE113TU
# {'postcode': 'LE11 3TU', 'university': 'Loughborough University', 'latitude': 52.764828, 'longitude': -1.22952, 'region': 'East Midlands', 'API URL': 'https://api.postcodes.io/postcodes/LE113TU'}
# index 45
# NW44BT
# https://api.postcodes.io/postcodes/NW44BT
# {'postcode': 'NW4 4BT', 'university': 'Middlesex University', 'latitude': 51.589833, 'longitude': -0.22894499999999998, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/NW44BT'}
# index 46
# B323NT
# https://api.postcodes.io/postcodes/B323NT
# {'postcode': 'B32 3NT', 'university': 'Newman University College', 'latitude': 52.434122, 'longitude': -1.995028, 'region': 'West Midlands', 'API URL': 'https://api.postcodes.io/postcodes/B323NT'}
# index 47
# LS74BH
# https://api.postcodes.io/postcodes/LS74BH
# {'postcode': 'LS7 4BH', 'university': 'Northern School of Contemporary Dance', 'latitude': 53.813069, 'longitude': -1.533471, 'region': 'Yorkshire and The Humber', 'API URL': 'https://api.postcodes.io/postcodes/LS74BH'}
# index 48
# NR24SN
# https://api.postcodes.io/postcodes/NR24SN
# {'postcode': 'NR2 4SN', 'university': 'Norwich University College of the Arts', 'latitude': 52.630494, 'longitude': 1.297272, 'region': 'East of England', 'API URL': 'https://api.postcodes.io/postcodes/NR24SN'}
# index 49
# NG14BU
# https://api.postcodes.io/postcodes/NG14BU
# {'postcode': 'NG1 4BU', 'university': 'Nottingham Trent University', 'latitude': 52.956436, 'longitude': -1.152077, 'region': 'East Midlands', 'API URL': 'https://api.postcodes.io/postcodes/NG14BU'}
# index 50
# MK76AA
# https://api.postcodes.io/postcodes/MK76AA
# {'postcode': 'MK7 6AA', 'university': 'Open University(The)', 'latitude': 52.024914, 'longitude': -0.709747, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/MK76AA'}
# index 51
# OX30BP
# https://api.postcodes.io/postcodes/OX30BP
# {'postcode': 'OX3 0BP', 'university': 'Oxford Brookes University', 'latitude': 51.75438, 'longitude': -1.2232, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/OX30BP'}
# index 52
# SY232AX
# https://api.postcodes.io/postcodes/SY232AX
# {'postcode': 'SY23 2AX', 'university': 'Prifysgol Aberystwyth', 'latitude': 52.403464, 'longitude': -4.043584, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/SY232AX'}
# index 53
# EH216UU
# https://api.postcodes.io/postcodes/EH216UU
# {'postcode': 'EH21 6UU', 'university': 'Queen Margaret University, Edinburgh', 'latitude': 55.931281, 'longitude': -3.073057, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/EH216UU'}
# index 54
# E14NS
# https://api.postcodes.io/postcodes/E14NS
# {'postcode': 'E1 4NS', 'university': 'Queen Mary and Westfield College, University of London', 'latitude': 51.524636, 'longitude': -0.04071, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/E14NS'}
# index 55
# SE100EW
# https://api.postcodes.io/postcodes/SE100EW
# {'postcode': 'SE10 0EW', 'university': 'Ravensbourne Limited', 'latitude': 51.501677, 'longitude': 0.005678, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SE100EW'}
# index 56
# SW155PJ
# https://api.postcodes.io/postcodes/SW155PJ
# {'postcode': 'SW15 5PJ', 'university': 'Roehampton University', 'latitude': 51.45516, 'longitude': -0.246917, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SW155PJ'}
# index 57
# DA159DF
# https://api.postcodes.io/postcodes/DA159DF
# {'postcode': 'DA15 9DF', 'university': 'Rose Bruford College', 'latitude': 51.439376, 'longitude': 0.107096, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/DA159DF'}
# index 58
# NW15HT
# https://api.postcodes.io/postcodes/NW15HT
# {'postcode': 'NW1 5HT', 'university': 'Royal Academy of Music', 'latitude': 51.523497, 'longitude': -0.1517, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/NW15HT'}
# index 59
# GL76JS
# https://api.postcodes.io/postcodes/GL76JS
# {'postcode': 'GL7 6JS', 'university': 'Royal Agricultural College', 'latitude': 51.709508, 'longitude': -1.994916, 'region': 'South West', 'API URL': 'https://api.postcodes.io/postcodes/GL76JS'}
# index 60
# SW72EU
# https://api.postcodes.io/postcodes/SW72EU
# {'postcode': 'SW7 2EU', 'university': 'Royal College of Art(The)', 'latitude': 51.501354, 'longitude': -0.178473, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SW72EU'}
# index 61
# SW72BS
# https://api.postcodes.io/postcodes/SW72BS
# {'postcode': 'SW7 2BS', 'university': 'Royal College of Music', 'latitude': 51.499279, 'longitude': -0.176913, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SW72BS'}
# index 62
# G23DB
# https://api.postcodes.io/postcodes/G23DB
# {'postcode': 'G2 3DB', 'university': 'Royal Conservatoire of Scotland', 'latitude': 55.865813, 'longitude': -4.257595, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/G23DB'}
# index 63
# TW200EX
# https://api.postcodes.io/postcodes/TW200EX
# {'postcode': 'TW20 0EX', 'university': 'Royal Holloway College and Bedford New College', 'latitude': 51.424814, 'longitude': -0.5667449999999999, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/TW200EX'}
# index 64
# M139RD
# https://api.postcodes.io/postcodes/M139RD
# {'postcode': 'M13 9RD', 'university': 'Royal Northern College of Music', 'latitude': 53.468557, 'longitude': -2.236963, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/M139RD'}
# index 65
# CF103ER
# https://api.postcodes.io/postcodes/CF103ER
# {'postcode': 'CF10 3ER', 'university': 'Royal Welsh College of Music and Drama Limited', 'latitude': 51.485644, 'longitude': -3.183856, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/CF103ER'}
# index 66
# WC1H0XG
# https://api.postcodes.io/postcodes/WC1H0XG
# {'postcode': 'WC1H 0XG', 'university': 'School of Oriental and African Studies', 'latitude': 51.52235, 'longitude': -0.12925899999999999, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC1H0XG'}
# index 67
# WC1N1AX
# https://api.postcodes.io/postcodes/WC1N1AX
# {'postcode': 'WC1N 1AX', 'university': 'School of Pharmacy University of London(The)', 'latitude': 51.525083, 'longitude': -0.122458, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC1N1AX'}
# index 68
# S11WB
# https://api.postcodes.io/postcodes/S11WB
# {'postcode': 'S1 1WB', 'university': 'Sheffield Hallam University', 'latitude': 53.379194, 'longitude': -1.465255, 'region': 'Yorkshire and The Humber', 'API URL': 'https://api.postcodes.io/postcodes/S11WB'}
# index 69
# SO140YN
# https://api.postcodes.io/postcodes/SO140YN
# {'postcode': 'SO14 0YN', 'university': 'Southampton Solent University', 'latitude': 50.90759, 'longitude': -1.401021, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/SO140YN'}
# index 70
# EH93JG
# https://api.postcodes.io/postcodes/EH93JG
# {'postcode': 'EH9 3JG', 'university': 'Sruc', 'latitude': 55.921623, 'longitude': -3.176228, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/EH93JG'}
# index 71
# SW170RE
# https://api.postcodes.io/postcodes/SW170RE
# {'postcode': 'SW17 0RE', 'university': "St George's Hospital Medical School", 'latitude': 51.427798, 'longitude': -0.175228, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SW170RE'}
# index 72
# BT126FE
# https://api.postcodes.io/postcodes/BT126FE
# {'postcode': 'BT12 6FE', 'university': "St Mary's University College", 'latitude': 54.593162, 'longitude': -5.961323, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/BT126FE'}
# index 73
# TW14SX
# https://api.postcodes.io/postcodes/TW14SX
# {'postcode': 'TW1 4SX', 'university': "St Mary's University College, Twickenham", 'latitude': 51.436152, 'longitude': -0.335907, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/TW14SX'}
# index 74
# ST42DE
# https://api.postcodes.io/postcodes/ST42DE
# {'postcode': 'ST4 2DE', 'university': 'Staffordshire University', 'latitude': 53.009202, 'longitude': -2.180352, 'region': 'West Midlands', 'API URL': 'https://api.postcodes.io/postcodes/ST42DE'}
# index 75
# BT95DY
# https://api.postcodes.io/postcodes/BT95DY
# {'postcode': 'BT9 5DY', 'university': 'Stranmillis University College', 'latitude': 54.572355, 'longitude': -5.939164, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/BT95DY'}
# index 76
# SA16ED
# https://api.postcodes.io/postcodes/SA16ED
# {'postcode': 'SA1 6ED', 'university': 'Swansea Metropolitan University', 'latitude': 51.624654, 'longitude': -3.949428, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/SA16ED'}
# index 77
# SA28PP
# https://api.postcodes.io/postcodes/SA28PP
# {'postcode': 'SA2 8PP', 'university': 'Swansea University', 'latitude': 51.609627, 'longitude': -3.980616, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/SA28PP'}
# index 78
# TS13BA
# https://api.postcodes.io/postcodes/TS13BA
# {'postcode': 'TS1 3BA', 'university': 'Teesside University', 'latitude': 54.572076, 'longitude': -1.234694, 'region': 'North East', 'API URL': 'https://api.postcodes.io/postcodes/TS13BA'}
# index 79
# BH125HH
# https://api.postcodes.io/postcodes/BH125HH
# {'postcode': 'BH12 5HH', 'university': 'The Arts University College at Bournemouth', 'latitude': 50.741808, 'longitude': -1.8977279999999999, 'region': 'South West', 'API URL': 'https://api.postcodes.io/postcodes/BH125HH'}
# index 80
# EC1V0HB
# https://api.postcodes.io/postcodes/EC1V0HB
# {'postcode': 'EC1V 0HB', 'university': 'The City University', 'latitude': 51.527903, 'longitude': -0.103099, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/EC1V0HB'}
# index 81
# WC1H9JJ
# https://api.postcodes.io/postcodes/WC1H9JJ
# {'postcode': 'WC1H 9JJ', 'university': 'The Conservatoire for Dance and Drama', 'latitude': 51.526367, 'longitude': -0.128391, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC1H9JJ'}
# index 82
# L19HF
# https://api.postcodes.io/postcodes/L19HF
# {'postcode': 'L1 9HF', 'university': 'The Liverpool Institute for Performing Arts', 'latitude': 53.399657, 'longitude': -2.972271, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/L19HF'}
# index 83
# M156BH
# https://api.postcodes.io/postcodes/M156BH
# {'postcode': 'M15 6BH', 'university': 'The Manchester Metropolitan University', 'latitude': 53.470917, 'longitude': -2.239115, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/M156BH'}
# index 84
# BT71NN
# https://api.postcodes.io/postcodes/BT71NN
# {'postcode': 'BT7 1NN', 'university': "The Queen's University of Belfast", 'latitude': 54.584772, 'longitude': -5.934438, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/BT71NN'}
# index 85
# AB107FY
# https://api.postcodes.io/postcodes/AB107FY
# {'postcode': 'AB10 7FY', 'university': 'The Robert Gordon University', 'latitude': 57.117949, 'longitude': -2.144044, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/AB107FY'}
# index 86
# NW10TU
# https://api.postcodes.io/postcodes/NW10TU
# {'postcode': 'NW1 0TU', 'university': 'The Royal Veterinary College', 'latitude': 51.536851, 'longitude': -0.133524, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/NW10TU'}
# index 87
# BL35AB
# https://api.postcodes.io/postcodes/BL35AB
# {'postcode': 'BL3 5AB', 'university': 'The University of Bolton', 'latitude': 53.573511, 'longitude': -2.436238, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/BL35AB'}
# index 88
# MK181EG
# https://api.postcodes.io/postcodes/MK181EG
# {'postcode': 'MK18 1EG', 'university': 'The University of Buckingham', 'latitude': 51.995998, 'longitude': -0.9918389999999999, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/MK181EG'}
# index 89
# PO196PE
# https://api.postcodes.io/postcodes/PO196PE
# {'postcode': 'PO19 6PE', 'university': 'The University of Chichester', 'latitude': 50.84431, 'longitude': -0.7750100000000001, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/PO196PE'}
# index 90
# CA12HH
# https://api.postcodes.io/postcodes/CA12HH
# {'postcode': 'CA1 2HH', 'university': 'The University of Cumbria', 'latitude': 54.891163, 'longitude': -2.921417, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/CA12HH'}
# index 91
# M139PL
# https://api.postcodes.io/postcodes/M139PL
# {'postcode': 'M13 9PL', 'university': 'The University of Manchester', 'latitude': 53.466926, 'longitude': -2.233578, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/M139PL'}
# index 92
# NN25PH
# https://api.postcodes.io/postcodes/NN25PH
# index 93
# W55RF
# https://api.postcodes.io/postcodes/W55RF
# {'postcode': 'W5 5RF', 'university': 'The University of West London', 'latitude': 51.507259, 'longitude': -0.303013, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/W55RF'}
# index 94
# W1B2HW
# https://api.postcodes.io/postcodes/W1B2HW
# {'postcode': 'W1B 2HW', 'university': 'The University of Westminster', 'latitude': 51.516978, 'longitude': -0.14306000000000002, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/W1B2HW'}
# index 95
# SE109JF
# https://api.postcodes.io/postcodes/SE109JF
# {'postcode': 'SE10 9JF', 'university': 'Trinity Laban Conservatoire of Music and Dance Ltd', 'latitude': 51.483587, 'longitude': -0.0071979999999999995, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/SE109JF'}
# index 96
# IP41QJ
# https://api.postcodes.io/postcodes/IP41QJ
# {'postcode': 'IP4 1QJ', 'university': 'University Campus Suffolk Ltd', 'latitude': 52.052548, 'longitude': 1.162595, 'region': 'East of England', 'API URL': 'https://api.postcodes.io/postcodes/IP41QJ'}
# index 97
# B31JB
# https://api.postcodes.io/postcodes/B31JB
# {'postcode': 'B3 1JB', 'university': 'University College Birmingham', 'latitude': 52.48184, 'longitude': -1.905939, 'region': 'West Midlands', 'API URL': 'https://api.postcodes.io/postcodes/B31JB'}
# index 98
# TR114RH
# https://api.postcodes.io/postcodes/TR114RH
# {'postcode': 'TR11 4RH', 'university': 'University College Falmouth', 'latitude': 50.149625, 'longitude': -5.071079, 'region': 'South West', 'API URL': 'https://api.postcodes.io/postcodes/TR114RH'}
# index 99
# WC1E6BT
# https://api.postcodes.io/postcodes/WC1E6BT
# {'postcode': 'WC1E 6BT', 'university': 'University College London', 'latitude': 51.523569, 'longitude': -0.132424, 'region': 'London', 'API URL': 'https://api.postcodes.io/postcodes/WC1E6BT'}
# index 100
# GU97DS
# https://api.postcodes.io/postcodes/GU97DS
# {'postcode': 'GU9 7DS', 'university': 'University for the Creative Arts', 'latitude': 51.216479, 'longitude': -0.8054939999999999, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/GU97DS'}
# index 101
# AB243FX
# https://api.postcodes.io/postcodes/AB243FX
# {'postcode': 'AB24 3FX', 'university': 'University of Aberdeen', 'latitude': 57.164841, 'longitude': -2.1002359999999998, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/AB243FX'}
# index 102
# DD11HG
# https://api.postcodes.io/postcodes/DD11HG
# {'postcode': 'DD1 1HG', 'university': 'University of Abertay Dundee', 'latitude': 56.463117, 'longitude': -2.974299, 'region': None, 'API URL': 'https://api.postcodes.io/postcodes/DD11HG'}
# index 103
# BA27AY
# https://api.postcodes.io/postcodes/BA27AY
# {'postcode': 'BA2 7AY', 'university': 'University of Bath (The)', 'latitude': 51.379324, 'longitude': -2.327157, 'region': 'South West', 'API URL': 'https://api.postcodes.io/postcodes/BA27AY'}
# index 104
# LU13JU
# https://api.postcodes.io/postcodes/LU13JU
# {'postcode': 'LU1 3JU', 'university': 'University of Bedfordshire', 'latitude': 51.87825, 'longitude': -0.411539, 'region': 'East of England', 'API URL': 'https://api.postcodes.io/postcodes/LU13JU'}
# index 105
# B152TT
# https://api.postcodes.io/postcodes/B152TT
# {'postcode': 'B15 2TT', 'university': 'University of Birmingham', 'latitude': 52.453282, 'longitude': -1.92789, 'region': 'West Midlands', 'API URL': 'https://api.postcodes.io/postcodes/B152TT'}
# index 106
# BD71DP
# https://api.postcodes.io/postcodes/BD71DP
# {'postcode': 'BD7 1DP', 'university': 'University of Bradford', 'latitude': 53.791242, 'longitude': -1.7662309999999999, 'region': 'Yorkshire and The Humber', 'API URL': 'https://api.postcodes.io/postcodes/BD71DP'}
# index 107
# BN24AT
# https://api.postcodes.io/postcodes/BN24AT
# {'postcode': 'BN2 4AT', 'university': 'University of Brighton', 'latitude': 50.842454, 'longitude': -0.11917000000000001, 'region': 'South East', 'API URL': 'https://api.postcodes.io/postcodes/BN24AT'}
# index 108
# BS81TH
# https://api.postcodes.io/postcodes/BS81TH
# {'postcode': 'BS8 1TH', 'university': 'University of Bristol', 'latitude': 51.459066, 'longitude': -2.603291, 'region': 'South West', 'API URL': 'https://api.postcodes.io/postcodes/BS81TH'}
# index 109
# CB21TN
# https://api.postcodes.io/postcodes/CB21TN
# {'postcode': 'CB2 1TN', 'university': 'University of Cambridge', 'latitude': 52.205105, 'longitude': 0.11617899999999999, 'region': 'East of England', 'API URL': 'https://api.postcodes.io/postcodes/CB21TN'}
# index 110
# PR12HE
# https://api.postcodes.io/postcodes/PR12HE
# {'postcode': 'PR1 2HE', 'university': 'University of Central Lancashire', 'latitude': 53.761338, 'longitude': -2.7073840000000002, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/PR12HE'}
# index 111
# CH14BJ
# https://api.postcodes.io/postcodes/CH14BJ
# {'postcode': 'CH1 4BJ', 'university': 'University of Chester', 'latitude': 53.198604, 'longitude': -2.898165, 'region': 'North West', 'API URL': 'https://api.postcodes.io/postcodes/CH14BJ'}
# index 112
# DE221GB
# https://api.postcodes.io/postcodes/DE221GB
